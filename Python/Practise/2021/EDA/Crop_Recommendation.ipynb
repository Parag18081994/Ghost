# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/Gladiator07/Harvestify/master/Data-processed/crop_recommendation.csv')
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.rename(columns={"label":"crop"},inplace=True)

# %%
df.describe().T
# Out:
#               count        mean        std        min        25%        50%  \
# N            2200.0   50.551818  36.917334   0.000000  21.000000  37.000000
# P            2200.0   53.362727  32.985883   5.000000  28.000000  51.000000
# K            2200.0   48.149091  50.647931   5.000000  20.000000  32.000000
# temperature  2200.0   25.616244   5.063749   8.825675  22.769375  25.598693
# humidity     2200.0   71.481779  22.263812  14.258040  60.261953  80.473146
# ph           2200.0    6.469480   0.773938   3.504752   5.971693   6.425045
# rainfall     2200.0  103.463655  54.958389  20.211267  64.551686  94.867624
#
#                     75%         max
# N             84.250000  140.000000
# P             68.000000  145.000000
# K             49.000000  205.000000
# temperature   28.561654   43.675493
# humidity      89.948771   99.981876
# ph             6.923643    9.935091
# rainfall     124.267508  298.560117

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# crop            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# crop           0
# dtype: int64

# %%
df['crop'].value_counts()
# Out:
# orange         100
# mothbeans      100
# mango          100
# blackgram      100
# cotton         100
# pigeonpeas     100
# grapes         100
# rice           100
# chickpea       100
# pomegranate    100
# jute           100
# banana         100
# coconut        100
# kidneybeans    100
# watermelon     100
# muskmelon      100
# apple          100
# lentil         100
# mungbean       100
# maize          100
# papaya         100
# coffee         100
# Name: crop, dtype: int64

# %%
l=df['crop'].unique()

# %% [markdown]
# # Attributes Correlation

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,linewidths=0.4)
plt.title("Attributes Correlation \n",fontsize=20)
plt.show()

# %% [markdown]
# # Level Nitrogen content in soil suitable for specific crops

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='crop',y='N',data=df)
plt.title("Types of crop and suitable value of Nitrogen content in soil \n",fontsize=20)
plt.xticks(rotation=25)
plt.xlabel("Types of crops",fontsize=20)
plt.ylabel(" ratio of Nitrogen content in soil",fontsize=20)
plt.show()

# %% [markdown]
# # Level Phosphorus content in soil suitable for specific crops

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='crop',y='P',data=df)
plt.title("Types of crop and suitable value of Phosphorus content in soil \n",fontsize=20)
plt.xticks(rotation=25)
plt.xlabel("Types of crops",fontsize=20)
plt.ylabel(" ratio of Phosphorous content in soil",fontsize=20)
plt.show()

# %% [markdown]
# # Level Potassium content in soil suitable for specific crops

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='crop',y='K',data=df)
plt.title("Types of crop and suitable value of Potassium content in soil \n",fontsize=20)
plt.xticks(rotation=25)
plt.xlabel("Types of crops",fontsize=20)
plt.ylabel(" ratio of Potassium content in soil",fontsize=20)
plt.show()

# %%
sns.catplot(y='temperature',x='crop',data=df,aspect=4)
plt.title("Relation of various crops with Temperature range",fontsize=20)
plt.xticks(np.arange(22),(l),fontsize=15,rotation=20)
plt.xlabel("Type of crops ",fontsize=20)
plt.ylabel("Temperature",fontsize=20)
plt.show()
plt.show()

# %%
sns.catplot(y='humidity',x='crop',data=df,aspect=4)
plt.title("Relation of various crops with Humidity range",fontsize=20)
plt.xticks(np.arange(22),(l),fontsize=15,rotation=20)
plt.xlabel("Type of crops ",fontsize=20)
plt.ylabel("Humidity in %",fontsize=20)
plt.show()
plt.show()

# %%
sns.catplot(y='ph',x='crop',data=df,aspect=4)
plt.title("Relation of various crops with pH vale",fontsize=20)
plt.xticks(np.arange(22),(l),fontsize=15,rotation=20)
plt.xlabel("Type of crops ",fontsize=20)
plt.ylabel("pH value",fontsize=20)
plt.show()
plt.show()

# %%
sns.catplot(y='rainfall',x='crop',data=df,aspect=4)
plt.title("Relation Rainfall with various crops with rainfall",fontsize=20)
plt.xticks(np.arange(22),(l),fontsize=15,rotation=20)
plt.xlabel("Type of crops ",fontsize=20)
plt.ylabel("Rainfall in mm",fontsize=20)
plt.show()
plt.show()
