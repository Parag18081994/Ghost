# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
draft1=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\ex1.csv')
draft1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
type(draft1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Head

# %%
draft1.head(2)
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %% [markdown]
# Tail

# %%
#draft1.tail(1)
draft1.tail()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# To read a tab seperated file-test.tsv

# %%
draft2=pd.read_table(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\test.tsv')
draft2
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %% [markdown]
# Dont want the first line of file as header

# %%
pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\ex1.csv',header=None)
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\ex2.csv',names=['abc','xyz','Pqr','cde','parag','naik'])
df
# Out:
#    abc  xyz  Pqr  cde  parag  naik
# 0    1    2    3    4  hello   NaN
# 1    5    6    7    8  world   NaN
# 2    9   10   11   12    foo   NaN

# %% [markdown]
# Multi-Level indexing

# %%
parsed=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\csv_mindex.csv')
parsed
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
parsed=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\csv_mindex.csv',index_col=['key1'])
parsed
# Out:
#      key2  value1  value2
# key1
# one     a       1       2
# one     b       3       4
# one     c       5       6
# one     d       7       8
# two     a       9      10
# two     b      11      12
# two     c      13      14
# two     d      15      16

# %%
parsed=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\csv_mindex.csv',index_col=['key1','key2'])
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
df=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\ex4.csv')
df
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
#here 0 starts from #hey then count 2 and 3
df=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\ex4.csv',skiprows=[0,2,3])
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
result=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\code_pandas1\examples\ex5.csv')
result
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
draft3=pd.read_excel(r'C:\Users\Admin\iNeuron_Machine_Learning\code_pandas1\examples\test1.xlsx')
draft3.head(6)
# Out:
#      abc  dfsdf      sdfsd sdfsd.1 Unnamed: 4 Unnamed: 5
# 0    NaN    NaN        NaN     NaN        NaN        sdf
# 1  sdfsd    NaN      sdfsd     NaN      sdfsd        NaN
# 2  sdfsd    NaN        NaN   sdfsd        NaN        NaN
# 3    NaN    NaN  dfsdbdvfh     NaN        dfs        NaN
# 4    NaN    NaN        NaN     NaN       dfsd        NaN
# 5    NaN    NaN        NaN   sdfsd        NaN        NaN

# %% [markdown]
# using multiple sheet in excel from Sheet3

# %%
#using multiple sheet in excel-by default it will pick first sheet i.e-abc
draft3=pd.read_excel(r'C:\Users\Admin\iNeuron_Machine_Learning\code_pandas1\examples\test1.xlsx',sheet_name='Sheet2')
draft3.head(6)
# Out:
#    fds   fhgf Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0  NaN    NaN        NaN      ghjdf      gfhgf
# 1  NaN    NaN   sdfsdjyt        NaN        NaN
# 2  NaN  fgfdg        NaN        NaN        NaN
# 3   jh    NaN        NaN        NaN        NaN
# 4  NaN    NaN        NaN       bhgj        NaN

# %% [markdown]
# Trying to read data from html file in local or https server

# %%
#it will be in form of [df1,df2,df3.....]
url='https://www.basketball-reference.com/leagues/NBA_2015_totals.html'
BB_data=pd.read_html(url)
BB_data
type(BB_data)
# Out:
# list

# %%
BB_data[0].head(5)
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
#we oly of one table at index-0
BB_data[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-1373dc629f4e> in <module>
# ----> 1 BB_data[1]
#
# IndexError: list index out of range

# %%
df=BB_data[0]
df.head(5)
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df.tail(9)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 666  486   Dorell Wright  SF  29  POR  48   2   592   72  190  ...  .810   14
# 667  487     Tony Wroten  PG  21  PHI  30  15   895  175  434  ...  .667   22
# 668  488     James Young  SG  19  BOS  31   0   332   36  102  ...  .552    9
# 669  489      Nick Young  SG  29  LAL  42   0  1000  174  476  ...  .892   17
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 666   97  111   41   20  11   18   55   219
# 667   64   86  157   48   8  113   72   507
# 668   33   42   13    8   2    5   22   105
# ...

# %%
df['MP'] #finding a specific columne
# Out:
# 0      1287
# 1       248
# 2      1771
# 3       215
# 4      2502
#        ...
# 670    2434
# 671    1605
# 672     829
# 673    1487
# 674    1731
# Name: MP, Length: 675, dtype: object

# %% [markdown]
# read multiple columne as below will give error but we need to pass it as a list in cell-19

# %%
#read multiple col
df['MP','Tm']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3_new\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('MP', 'Tm')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ee519667a1b4> in <module>
#       1 #read multiple col
# ...

# %%
#calling in a list
df[['MP','Tm']]
# Out:
#        MP   Tm
# 0    1287  NYK
# 1     248  MEM
# 2    1771  OKC
# 3     215  MIN
# 4    2502  TOT
# ..    ...  ...
# 670  2434  TOT
# 671  1605  MIN
# 672   829  BRK
# 673  1487  CHO
# 674  1731  BOS
#
# [675 rows x 2 columns]

# %% [markdown]
# if trying to read out one col inside a list it is a datafram

# %%
type(df['MP']) #series
type(df[['MP']]) #dataframe due to []
# Out:
# pandas.core.frame.DataFrame

# %%
df[['MP','ORB']].head(5)
# Out:
#      MP  ORB
# 0  1287   79
# 1   248    9
# 2  1771  199
# 3   215   23
# 4  2502   27

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# Reading a data from git

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic_train[['Name','Pclass']].head(5)
# Out:
#                                                 Name  Pclass
# 0                            Braund, Mr. Owen Harris       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                             Heikkinen, Miss. Laina       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                           Allen, Mr. William Henry       3

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Example-1
# 1.reading this data in DataFrame
# 2.Print first five data
# 3.print last 2 data
# 4.give your own columne name(change a columne name
# 5.select oen col and print its data type
# 6.print datatype
# 7.check data if anydata is null
# 8.skip random row

# %%
bank_addition=pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')

# %%
#-1
bank_addition
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
#-2
bank_addition.head(5)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
#-3
bank_addition.tail(2)
# Out:
#        age         job  marital            education default housing loan  \
# 41186   44  technician  married  professional.course      no      no   no
# 41187   74     retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [2 rows x 21 columns]

# %%
#-4 change the col name(error)--Wrong
bank_addition_2=pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';',index_col=[['parag', 'job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
       'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']])
bank_addition_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-f91dd7f00920> in <module>
#       3        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#       4        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
# ----> 5        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y']])
#       6 bank_addition_2
#
# ...

# %%
#use this to rename a col change the values
#bank_addition.rename(columns={'age':'parag'})

# %%
#-5
bank_addition['age'].dtype
# Out:
# dtype('int64')

# %%
#-6
bank_addition.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
#-7
#pd.isnull(bank_addition)
bank_addition.isnull()
bank_addition.isnull().sum() #will give summation
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#-8.skip random row
bank_addition_1=pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';',skiprows=[1,2,3])
bank_addition_1
# Out:
#        age          job  marital            education  default housing loan  \
# 0       40       admin.  married             basic.6y       no      no   no
# 1       56     services  married          high.school       no      no  yes
# 2       45     services  married             basic.9y  unknown      no   no
# 3       59       admin.  married  professional.course       no      no   no
# 4       41  blue-collar  married              unknown  unknown      no   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41180   73      retired  married  professional.course       no     yes   no
# 41181   46  blue-collar  married  professional.course       no      no   no
# 41182   56      retired  married    university.degree       no     yes   no
# 41183   44   technician  married  professional.course       no      no   no
# 41184   74      retired  married  professional.course       no     yes   no
#
# ...
