# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'https://raw.githubusercontent.com/PramodShenoy/911-Calls/master/911.csv')
#df=pd.read_csv(r'C:\Users\pnaik27\Machine Learning iNeuron\Python\911.csv')
df
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %% [markdown]
# 1.Description for categorical and numerical

# %%
df.describe()
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %% [markdown]
# 7.title extract service detail

# %%
df['title'].unique()
# Out:
# array(['EMS: BACK PAINS/INJURY', 'EMS: DIABETIC EMERGENCY',
#        'Fire: GAS-ODOR/LEAK', 'EMS: CARDIAC EMERGENCY', 'EMS: DIZZINESS',
#        'EMS: HEAD INJURY', 'EMS: NAUSEA/VOMITING',
#        'EMS: RESPIRATORY EMERGENCY', 'EMS: SYNCOPAL EPISODE',
#        'Traffic: VEHICLE ACCIDENT -', 'EMS: VEHICLE ACCIDENT',
#        'Traffic: DISABLED VEHICLE -', 'Fire: APPLIANCE FIRE',
#        'EMS: GENERAL WEAKNESS', 'Fire: CARBON MONOXIDE DETECTOR',
#        'EMS: UNKNOWN MEDICAL EMERGENCY', 'EMS: UNRESPONSIVE SUBJECT',
#        'Fire: VEHICLE ACCIDENT', 'EMS: ALTERED MENTAL STATUS',
#        'Fire: FIRE ALARM', 'EMS: CVA/STROKE',
#        'Traffic: ROAD OBSTRUCTION -', 'EMS: SUBJECT IN PAIN',
#        'EMS: HEMORRHAGING', 'EMS: FALL VICTIM', 'EMS: ASSAULT VICTIM',
#        'EMS: SEIZURES', 'EMS: MEDICAL ALERT ALARM',
#        'EMS: ABDOMINAL PAINS', 'Fire: PUMP DETAIL',
#        'Fire: FIRE INVESTIGATION', 'EMS: OVERDOSE', 'EMS: MATERNITY',
# ...

# %% [markdown]
# 2.Lattitude->type cast(float) to int->then perform groupby->count

# %%
df['lat']=df['lat'].astype(int) #typecasted to int

# %%
df.groupby('lat').count() #grouped and then took count
# Out:
#        lng   desc    zip  title  timeStamp    twp   addr      e
# lat
# 30       1      1      1      1          1      1      1      1
# 32       1      1      1      1          1      1      1      1
# 39    1477   1477   1415   1477       1477   1477   1475   1477
# 40   98012  98012  85219  98012      98012  97970  97495  98012
# 41       1      1      1      1          1      0      1      1

# %% [markdown]
# Extra work-

# %%
df['lat']==41
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99487    False
# 99488    False
# 99489    False
# 99490    False
# 99491    False
# Name: lat, Length: 99492, dtype: bool

# %%
a=np.where(df['lat']==41)
df.iloc[a]
# Out:
#       lat       lng                                           desc      zip  \
# 8367   41 -76.87403  MAIN;  ; Station 308A; 2016-01-02 @ 13:01:30;  17752.0
#
#                                title            timeStamp  twp  addr  e
# 8367  EMS: UNKNOWN MEDICAL EMERGENCY  2016-01-02 13:06:00  NaN  MAIN  1

# %% [markdown]
# 3.How many people are from same zip location

# %%
df['zip'].isnull().sum()
# Out:
# 12855

# %%
#count always give non-null values
df['zip'].count()
# Out:
# 86637

# %%
df_zip=df.groupby(['zip']).sum()

# %%
print(' zip\t  Number of people living in zip\n','-'*45)
print(df_zip['e'])
# Out:
#  zip	  Number of people living in zip
#  ---------------------------------------------
# zip
# 17752.0      1
# 18036.0      2
# 18041.0    414
# 18054.0    326
# 18056.0      6
#           ...
# 19512.0    220
# 19518.0     57
# 19525.0    965
# 36107.0      1
# 77316.0      1
# Name: e, Length: 104, dtype: int64

# %% [markdown]
# #extra work

# %%
a=np.where(df['zip']==18056.0 )

# %%
df.iloc[a]
# Out:
#        lat        lng                                               desc  \
# 5701    40 -75.556029  LIBERTY CIR & CONSTITUTION DR;  BERKS COUNTY; ...
# 20192   40 -75.557332  SEISHOLTZVILLE RD & CONSTITUTION DR;  BERKS CO...
# 38370   40 -75.551566  SCHOOL HOUSE RD;  UPPER HANOVER; Station 369; ...
# 38371   40 -75.551566  SCHOOL HOUSE RD; UPPER HANOVER; 2016-03-16 @ 1...
# 58964   40 -75.552245  CHESTNUT ST & STAR RD;  BERKS COUNTY; Station ...
# 83219   40 -75.551566  SCHOOL HOUSE RD; UPPER HANOVER; 2016-07-14 @ 1...
#
#            zip                     title            timeStamp            twp  \
# 5701   18056.0    EMS: CARDIAC EMERGENCY  2015-12-25 09:57:00   BERKS COUNTY
# 20192  18056.0     EMS: VEHICLE ACCIDENT  2016-01-29 08:02:00   BERKS COUNTY
# 38370  18056.0     EMS: VEHICLE ACCIDENT  2016-03-16 14:32:00  UPPER HANOVER
# 38371  18056.0    Fire: VEHICLE ACCIDENT  2016-03-16 14:32:00  UPPER HANOVER
# ...

# %% [markdown]
# 4.Check time stamp ->datatype->extract day in new col

# %%
type(df['timeStamp'])
# Out:
# pandas.core.series.Series

# %%
df['timeStamp'].head()
# Out:
# 0    2015-12-10 17:40:00
# 1    2015-12-10 17:40:00
# 2    2015-12-10 17:40:00
# 3    2015-12-10 17:40:01
# 4    2015-12-10 17:40:01
# Name: timeStamp, dtype: object

# %%
print(2015-12-10.split('-'))
# Out:
#   File "<ipython-input-111-f9a8e9fdc4e2>", line 1
#     print(2015-12-10.split('-'))
#                          ^
# SyntaxError: invalid syntax

# %%
a='2015-12-10'
x=a.split('-')
x[-1]
# Out:
# '10'

# %%
def getting_day(x):
    date_comp=x.split(' ')
    #print(date_comp)
    a=date_comp[0]
    #print(type(a))
    day=a.split('-')
    df['day']=day[2]
    return df['day']

# %%
getting_day('2015-12-10 17:40:00')
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 99487    10
# 99488    10
# 99489    10
# 99490    10
# 99491    10
# Name: day, Length: 99492, dtype: object

# %%
df.drop('day',axis=1)
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %%
x='2015-12-10 17:40:00'
x.split(' ')

# %%
df['date']=df['timeStamp'].dt.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2c7b49c23492> in <module>
# ----> 1 df['date']=df['timeStamp'].dt.date
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# ...

# %%
d='2015-01-08 22:44:09' 
date=pd.to_datetime(d).date()
print(date)
# Out:
# 2015-01-08

# %%
df['date']=df['timeStamp'].split(' ')
#df['Date']=pd.to_datetime(a).date()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a4374779e2ff> in <module>
# ----> 1 df['date']=df['timeStamp'].split(' ')
#       2 #df['Date']=pd.to_datetime(a).date()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
a=df['timeStamp'].head(10)
df[['Date','Time']]=df.timeStamp.str.split(expand=True)

# %%
df
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %%
import pandas as pd 
   
# create a new data frame 
df = pd.DataFrame({'Name': ['John Larter', 'Robert Junior', 'Jonny Depp'], 
                   'Age':[32, 34, 36]}) 
   
#print("Given Dataframe is :\n",df) 
   
type(df['Name'])
df[]=df.Name.str.split(expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-3ea69d42583e> in <module>
#       9 type(df['Name'])
# ...

# %%
print("\nSplitting 'Name' column into two different columns :\n", 
                                  df.Name.str.split(expand=True))
