# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn,randint,uniform,sample

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('2019-06-07',periods=1000),columns=['values'])
ts=pd.Series(randn(1000),index=pd.date_range('2019-06-07',periods=1000))

# %%
df.head()
# Out:
#               values
# 2019-06-07 -0.926728
# 2019-06-08 -0.093506
# 2019-06-09 -0.212445
# 2019-06-10  0.543412
# 2019-06-11  0.811862

# %%
ts.head()
# Out:
# 2019-06-07    0.726736
# 2019-06-08    0.517191
# 2019-06-09    2.219186
# 2019-06-10    0.215954
# 2019-06-11    0.119605
# Freq: D, dtype: float64

# %%
type(df),type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot()

# %%
df.plot()

# %%
ts.plot(figsize=(10,10))

# %%
ts1=ts.cumsum()
ts1.head()
ts1.plot()

# %%
df1=df.cumsum()
df1.plot()

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax=iris.plot(figsize=(15,8),title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
df.plot(kind='bar')

# %%
sns.countplot('species',data=iris)

# %%
df=iris.drop(['species'],axis=1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
 df.iloc[0].plot(kind='bar')

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic['pclass'].plot(kind='bar')

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -2.532818  0.884754 -0.807456 -0.188414
# 1 -1.310207 -0.022883  0.259838 -0.826875
# 2 -0.379898 -0.966085  0.120888 -0.481696
# 3 -0.270679 -0.400533  0.071495 -0.749295
# 4 -1.111707 -0.105722  0.282669 -0.145828
# 5 -3.120887  0.328931  0.559958  0.109814
# 6 -1.500675 -0.280587 -0.804326 -1.111558
# 7  0.767493  0.332264  0.749697 -0.698927
# 8 -0.382381 -0.049020  0.698574  0.611832
# 9 -0.363044  0.110519  0.503465  0.723540

# %%
df.plot.bar()

# %%
df.plot(kind='bar')

# %%
df.plot.barh(figsize=(5,5))

# %%
iris.plot.hist(alpha=0.5)

# %%
iris['sepal_length'].plot.hist()

# %%
iris.plot(kind='hist',stacked=False,bins=100)

# %%
iris.plot(kind='hist',stacked=True,bins=50)

# %%
iris.plot(kind='hist',stacked=True,bins=50,orientation='horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=50)

# %%
Question-titanic
1.Plot a graph for fare price variation
2.Try to show survived in histogram

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# 1.Plot a graph for fare price variation

# %%
titanic['fare'].plot()

# %%
titanic['fare'].plot.bar()

# %% [markdown]
# 2.Try to show survived in histogram

# %%
titanic['survived'].plot.hist()

# %%
df=iris.drop(['species'],axis=1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color='r',alpha=0.8,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001DA6CD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001DE70EC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001DEA8E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001E19C0C8>]],
#       dtype=object)

# %%
df.plot.scatter(x='sepal_length',y='petal_length')

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=80)

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',C='sepal_width',gridsize=10)

# %%
d=df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,10))

# %%
a=df.head(3).T

# %%
a
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
a.plot.pie(subplots=True,figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001FB15508>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FB0A548>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FB74808>],
#       dtype=object)

# %%
a.plot.pie(subplots=True,figsize=(20,20),fontsize=26,autopct='%0.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001FC35C48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FB10A48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FCCC1C8>],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(10,10),diagonal='kde',color='b')
plt.show()

# %%
ts.plot.kde()

# %%
df['sepal_length'].plot.kde()

# %%
df['petal_width'].plot.kde()

# %%
ts.plot(style='r--',label='Series',legend=True)

# %%
ts.plot(style='r *',label='Series',legend=True)

# %%
df.plot(legend=True,figsize=(10,5),logy=True)

# %%
df.plot(legend=True,figsize=(10,5),logy=True,subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000022328EC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000223EBC48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000223D2288>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000002247F2C8>],
#       dtype=object)

# %%
df.plot(subplots=True,sharex=False,layout=(2,3),figsize=(16,8))
plt.tight_layout()

# %% [markdown]
# # Plotly

# %%
import plotly as py

# %%
print(py.__version__)
# Out:
# 4.11.0

# %%
import cufflinks as cf

# %%
print(cf.__version__)
# Out:
# 0.17.3
